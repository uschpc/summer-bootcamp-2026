# %% [markdown]
# # Troubleshooting

# %% [markdown]
# ## What is wrong 1

# %% [raw]
# #!/bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition main
# #SBATCH --ntasks 1
# #SBATCH --mem 1g
# #SBATCH --nodes 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# # ----------------Commands------------------------
# python3 /home1/${USER}/script.py

# %% [markdown]
# ### Solution
#
# Click on the '...' below to see the solution.

# %% [raw]
# #SOLUTION#!
# /bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition main
# #SBATCH --ntasks 1
# #SBATCH --mem 1g
# #SBATCH --nodes 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load python
# source /home1/${USER}/my_python_env/bin/activate# ----------------Commands------------------------
# python3 /home1/${USER}/script.py

# %% [markdown]
# ## What is wrong 2

# %% [raw]
# #!/bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition main
# #SBATCH --ntasks 20
# #SBATCH --mem 10g
# #SBATCH --nodes 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load blast-plus
# # ----------------Commands------------------------
# blastn -query fasta.file -db database_name -outfmt 6 \
# -num_alignments 1 -num_descriptions 1 -out output_file

# %% [markdown]
# ### Solution
#
# Click on the '...' below to see the solution.

# %% [raw]
# #SOLUTION!
# #!/bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition main
# #SBATCH --ntasks 20
# #SBATCH --mem 10g
# #SBATCH --nodes 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load blast-plus
# # ----------------Commands------------------------
# blastn -query fasta.file -db database_name -outfmt 6 num_alignments 1 \ -num_descriptions 1 -out output_file -num_threads 20

# %% [raw]
# #Even better SOLUTION!
# #!/bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition main
# #SBATCH --ntasks 20
# #SBATCH --mem 10g
# #SBATCH --nodes 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load blast-plus
# # ----------------Commands------------------------
# blastn -query fasta.file -db database_name -outfmt 6 num_alignments 1 \ -num_descriptions 1 -out output_file -num_threads $SLURM_NTASKS

# %% [markdown]
# ## What is wrong 3

# %% [raw]
# #!/bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition main
# #SBATCH --ntasks 1
# #SBATCH --mem 500g
# #SBATCH --nodes 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load openblas
# module load r
# # ----------------Commands------------------------
# Rscript /home1/${USER}/R_example.R

# %% [markdown]
# ### Solution
#
# Click on the '...' below to see the solution.

# %% [raw]
# #SOLUTION!
# #!/bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition largemem
# #SBATCH --ntasks 1
# #SBATCH --mem 500g
# #SBATCH --nodes 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load openblas
# module load r
# # ----------------Commands------------------------
# Rscript /home1/${USER}/R_example.R

# %% [markdown]
# ## What is wrong 4

# %% [raw]
# #!/bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition gpu
# #SBATCH --nodes 1
# #SBATCH --mem 4g
# #SBATCH --ntasks 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load python
# source /home1/${USER}/my_python_env/bin/activate# ----------------Commands------------------------
# python3 /home1/${USER}/my_gpu_accelerated_script.py

# %% [markdown]
# ### Solution
#
# Click on the '...' below to see the solution.

# %% [raw]
# #SOLUTION!
# #!/bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition gpu
# #SBATCH --nodes 1
# #SBATCH --mem 4g
# #SBATCH --ntasks 1
# #SBATCH --gres gpu:a100:1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load python
# source /home1/${USER}/my_python_env/bin/activate# ----------------Commands------------------------
# python3 /home1/${USER}/my_gpu_accelerated_script.py

# %% [markdown]
# ## What is wrong 5

# %% [raw]
# # ----------------SLURM Parameters----------------
# #SBATCH --partition main
# #SBATCH --ntasks 1
# #SBATCH --mem 15g
# #SBATCH --nodes 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load samtools
# # ----------------Commands------------------------
# samtools stats example.bam

# %% [markdown]
# ### Solution
#
# Click on the '...' below to see the solution.

# %% [raw]
# #SOLUTION!
# #!/bin/bash
# # ----------------SLURM Parameters----------------
# #SBATCH --partition main
# #SBATCH --ntasks 1
# #SBATCH --mem 15g
# #SBATCH --nodes 1
# #SBATCH --chdir /home1/${USER}/summer-bootcamp-2026/04-running-jobs-on-carc-systems
# #SBATCH --account hpcsuppt_613
# # ----------------Load Modules--------------------
# module purge
# module load usc
# module load samtools
# # ----------------Commands------------------------
# samtools stats example.bam

# %% [markdown]
# ## What's Next?
#
# The last Notebook is [05-Summary.ipynb](./05-Summary.ipynb), which summarizes what we have learned so far.
